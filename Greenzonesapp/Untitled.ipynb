# %%
import random

key = ''.join(chr(random.randint(0, 0xFF)) for i in range(16))
print(key)
[x for x in key]
# Out:
# ôPèfR%=XFÇÉ_ì
# ['ô',
#  'P',
#  '\x81',
#  'è',
#  'f',
#  'R',
#  '%',
#  '=',
#  '\x9f',
#  'X',
#  'F',
#  'Ç',
#  'É',
#  '_',
#  '\x1e',
#  'ì']

# %%
iv = ''.join([chr(random.randint(0, 0xFF)) for i in range(16)])
print(iv)
# Out:
# ýô%	XúäxÍÓÅÎÛÔ

# %%
import subprocess
import sys

installed_packages = reqs = subprocess.check_output([sys.executable, '-m', 'pip', 'freeze']).decode('utf-8')
installed_packages = installed_packages.split('\r\n')
installed_packages = [pkg.split('==')[0] for pkg in installed_packages]
print(installed_packages)
# Out:
# ['absl-py', 'alabaster', 'anaconda-client', 'anaconda-navigator', 'asn1crypto', 'astor', 'astroid', 'attrs', 'Babel', 'backcall', 'backports.functools-lru-cache', 'backports.tempfile', 'backports.weakref', 'beautifulsoup4', 'bleach', 'boto', 'boto3', 'botocore', 'browsermob-proxy', 'bz2file', 'cachetools', 'certifi', 'cffi', 'chardet', 'Click', 'cloudpickle', 'clyent', 'colorama', 'conda', 'conda-build', 'conda-package-handling', 'conda-verify', 'crypto', 'cryptography', 'cycler', 'decorator', 'defusedxml', 'docutils', 'entrypoints', 'filelock', 'flake8', 'future', 'gast', 'gensim', 'glob2', 'google-auth', 'google-auth-oauthlib', 'google-pasta', 'grpcio', 'h5py', 'idna', 'imagesize', 'importlib-metadata', 'ipykernel', 'ipython', 'ipython-genutils', 'isort', 'jedi', 'Jinja2', 'jmespath', 'joblib', 'jsonschema', 'jupyter-client', 'jupyter-contrib-core', 'jupyter-contrib-nbextensions', 'jupyter-core', 'jupyter-highlight-selected-word', 'jupyter-latex-envs', 'jupyter-nbextensions-configurator', 'Keras', 'Keras-Applications', 'Keras-Preprocessing', 'keyring', 'kiwisolver', 'lazy-object-proxy', 'lxml', 'Markdown', 'MarkupSafe', 'matplotlib', 'mccabe', 'menuinst', 'mistune', 'mkl-fft', 'mkl-random', 'mkl-service', 'more-itertools', 'msgpack', 'Naked', 'navigator-updater', 'nbconvert', 'nbformat', 'notebook', 'numpy', 'numpydoc', 'oauthlib', 'olefile', 'opt-einsum', 'packaging', 'pandas', 'pandocfilters', 'parso', 'pickleshare', 'Pillow', 'pkginfo', 'prometheus-client', 'prompt-toolkit', 'protobuf', 'psutil', 'pyasn1', 'pyasn1-modules', 'pycodestyle', 'pycodestyle-magic', 'pycosat', 'pycparser', 'pycrypto', 'pycryptodome', 'pyflakes', 'Pygments', 'pylint', 'pyOpenSSL', 'pyparsing', 'pyreadline', 'pyrsistent', 'PySocks', 'python-dateutil', 'pytz', 'pywin32', 'pywin32-ctypes', 'pywinpty', 'PyYAML', 'pyzmq', 'QtAwesome', 'qtconsole', 'QtPy', 'requests', 'requests-oauthlib', 'rope', 'rsa', 'ruamel-yaml', 's3transfer', 'scikit-learn', 'scipy', 'selenium', 'Send2Trash', 'shellescape', 'six', 'smart-open', 'snowballstemmer', 'soupsieve', 'Sphinx', 'sphinxcontrib-applehelp', 'sphinxcontrib-devhelp', 'sphinxcontrib-htmlhelp', 'sphinxcontrib-jsmath', 'sphinxcontrib-qthelp', 'sphinxcontrib-serializinghtml', 'spyder', 'spyder-kernels', 'tensorboard', 'tensorflow', 'tensorflow-estimator', 'termcolor', 'terminado', 'testpath', 'TikTokApi', 'tornado', 'tqdm', 'traitlets', 'urllib3', 'wcwidth', 'webencodings', 'Werkzeug', 'win-inet-pton', 'wincertstore', 'wrapt', 'yapf', 'zipp', '']

# %%
from Crypto.Cipher import AES

aes = AES.new(key, AES.MODE_CBC, iv)
data = 'hello world 1234' # <- 16 bytes
encd = aes.encrypt(data)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-a19208c9ed3d> in <module>
# ----> 1 from Crypto.Cipher import AES
#       2
#       3 aes = AES.new(key, AES.MODE_CBC, iv)
#       4 data = 'hello world 1234' # <- 16 bytes
#       5 encd = aes.encrypt(data)
#
# ModuleNotFoundError: No module named 'Crypto'

# %%
class AESCipher(object):

    def __init__(self, key): 
        self.bs = AES.block_size
        self.key = hashlib.sha256(key.encode()).digest()

    def encrypt(self, raw):
        raw = self._pad(raw)
        iv = Random.new().read(AES.block_size)
        cipher = AES.new(self.key, AES.MODE_CBC, iv)
        return base64.b64encode(iv + cipher.encrypt(raw.encode()))

    def decrypt(self, enc):
        enc = base64.b64decode(enc)
        iv = enc[:AES.block_size]
        cipher = AES.new(self.key, AES.MODE_CBC, iv)
        return self._unpad(cipher.decrypt(enc[AES.block_size:])).decode('utf-8')

    def _pad(self, s):
        return s + (self.bs - len(s) % self.bs) * chr(self.bs - len(s) % self.bs)

    @staticmethod
    def _unpad(s):
        return s[:-ord(s[len(s)-1:])]

# %%
import sys
# !{sys.executable} -m pip install Crypto
# Out:
# Collecting Crypto
#   Downloading https://files.pythonhosted.org/packages/fc/bb/0b812dc02e6357606228edfbf5808f5ca0a675a84273578c3a199e841cd8/crypto-1.4.1-py2.py3-none-any.whl
# Collecting shellescape
#   Downloading https://files.pythonhosted.org/packages/d0/f4/0081137fceff5779cd4205c1e96657e41cc2d2d56c940dc8eeb6111780f7/shellescape-3.8.1-py2.py3-none-any.whl
# Collecting Naked
#   Downloading https://files.pythonhosted.org/packages/02/36/b8107b51adca73402ec1860d88f41d958e275e60eea6eeaa9c39ddb89a40/Naked-0.1.31-py2.py3-none-any.whl (590kB)
# Requirement already satisfied: pyyaml in c:\users\aavil\anaconda3\lib\site-packages (from Naked->Crypto) (5.2)
# Requirement already satisfied: requests in c:\users\aavil\anaconda3\lib\site-packages (from Naked->Crypto) (2.22.0)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\aavil\anaconda3\lib\site-packages (from requests->Naked->Crypto) (2.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\aavil\anaconda3\lib\site-packages (from requests->Naked->Crypto) (1.25.7)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\aavil\anaconda3\lib\site-packages (from requests->Naked->Crypto) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\aavil\anaconda3\lib\site-packages (from requests->Naked->Crypto) (2019.11.28)
# Installing collected packages: shellescape, Naked, Crypto
# Successfully installed Crypto-1.4.1 Naked-0.1.31 shellescape-3.8.1
